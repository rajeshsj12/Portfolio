# %%
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %sql mysql+pymysql://root:password@localhost:3306/

# %%
# %%sql
# SHOW DATABASES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 8 rows affected.
# [('ecom',),
#  ('information_schema',),
#  ('lastcourse',),
#  ('learn',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('test',)]

# %%
# %%sql
# USE ecom;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 5 rows affected.
# [('categories',), ('customers',), ('orderitems',), ('orders',), ('products',)]

# %%
# %%sql
# SELECT * FROM categories;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 20 rows affected.
# [(1, 'Electronics', 'Electronic gadgets and accessories'),
#  (2, 'Books', 'A wide range of reading material'),
#  (3, 'Clothing', 'Apparel for men, women, and children'),
#  (4, 'Home Goods', 'Items for your household'),
#  (5, 'Sports', 'Equipment and gear for various sports'),
#  (6, 'Toys', 'Playthings for all ages'),
#  (7, 'Beauty', 'Cosmetics and personal care products'),
#  (8, 'Jewelry', 'Fine and fashion jewelry'),
#  (9, 'Automotive', 'Parts and accessories for vehicles'),
#  (10, 'Health', 'Wellness and medical supplies'),
#  (11, 'Food & Beverage', 'Groceries and drinks'),
#  (12, 'Furniture', 'Items to furnish your home'),
#  (13, 'Tools', 'Equipment for DIY and professional use'),
#  (14, 'Garden', 'Supplies for outdoor and gardening'),
#  (15, 'Pet Supplies', 'Items for your furry friends'),
#  (16, 'Music', 'Instruments and accessories'),
#  (17, 'Art Supplies', 'Materials for creative endeavors'),
# ...

# %%
# %%sql
# select *
# from orders
# where orderstatus = 'pending' and totalamount > 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 2 rows affected.
# [(9, 9, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Pending', '666 Spruce Pl, Anytown', Decimal('89.99')),
#  (12, 12, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Pending', '999 Elm Ln, Anytown', Decimal('150.00'))]

# %%
# %%sql
# select * from orders;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 22 rows affected.
# [(1, 1, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Shipped', '123 Main St, Anytown', Decimal('1225.50')),
#  (2, 2, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Delivered', '456 Oak Ave, Anytown', Decimal('70.99')),
#  (3, 3, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Pending', '789 Pine Ln, Anytown', Decimal('25.00')),
#  (4, 4, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Shipped', '101 Elm Rd, Anytown', Decimal('18.20')),
#  (5, 5, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Delivered', '222 Maple Dr, Anytown', Decimal('110.50')),
#  (6, 6, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Pending', '333 Birch Ct, Anytown', Decimal('22.99')),
#  (7, 7, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Shipped', '444 Willow Way, Anytown', Decimal('12.75')),
#  (8, 8, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Delivered', '555 Cedar Blvd, Anytown', Decimal('550.00')),
# ...

# %%
# %%sql
# select * from orders where orderstatus="processing";
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 1 rows affected.
# [(21, 1, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Processing', '123 Main St, Anytown', Decimal('58.75'))]

# %%
# %%sql
# select * from customers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 20 rows affected.
# [(1, 'Alice', 'Smith', 'alice.smith@example.com', '9876543210', '123 Main St, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
#  (2, 'Bob', 'Johnson', 'bob.johnson@example.com', '8765432109', '456 Oak Ave, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
#  (3, 'Charlie', 'Brown', 'charlie.brown@example.com', '7654321098', '789 Pine Ln, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
#  (4, 'Diana', 'Miller', 'diana.miller@example.com', '6543210987', '101 Elm Rd, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
#  (5, 'Eve', 'Wilson', 'eve.wilson@example.com', '5432109876', '222 Maple Dr, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
#  (6, 'Frank', 'Taylor', 'frank.taylor@example.com', '4321098765', '333 Birch Ct, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
# ...

# %%
# %%sql
# select *
# from
#     orders inner join customers on orders.customerid = customers.customerid;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 22 rows affected.
# [(1, 1, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Shipped', '123 Main St, Anytown', Decimal('1225.50'), 1, 'Alice', 'Smith', 'alice.smith@example.com', '9876543210', '123 Main St, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
#  (21, 1, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Processing', '123 Main St, Anytown', Decimal('58.75'), 1, 'Alice', 'Smith', 'alice.smith@example.com', '9876543210', '123 Main St, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
#  (2, 2, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Delivered', '456 Oak Ave, Anytown', Decimal('70.99'), 2, 'Bob', 'Johnson', 'bob.johnson@example.com', '8765432109', '456 Oak Ave, Anytown', datetime.datetime(2025, 5, 20, 20, 38, 55)),
# ...

# %%
# %%sql
#
# show databases;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 8 rows affected.
# [('ecom',),
#  ('information_schema',),
#  ('lastcourse',),
#  ('learn',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('test',)]

# %%
# %%sql
#
#
#
# select * from lastcourse.customers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 5 rows affected.
# [(101, 'Alice Johnson', 'alice.johnson@example.com', '123 Maple St.'),
#  (102, 'Bob Smith', 'bob.smith@example.com', '456 Oak St.'),
#  (103, 'Charlie Brown', 'charlie.brown@example.com', '789 Pine St.'),
#  (104, 'David Wilson', 'david.wilson@example.com', '321 Elm St.'),
#  (105, 'Eva Green', 'eva.green@example.com', '654 Cedar St.')]

# %%
# %%sql
#
# select lastcourse.customers.name
# from lastcourse.customers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 5 rows affected.
# [('Alice Johnson',),
#  ('Bob Smith',),
#  ('Charlie Brown',),
#  ('David Wilson',),
#  ('Eva Green',)]

# %%
# %%sql
# select * from ecom.orders;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 22 rows affected.
# [(1, 1, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Shipped', '123 Main St, Anytown', Decimal('1225.50')),
#  (2, 2, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Delivered', '456 Oak Ave, Anytown', Decimal('70.99')),
#  (3, 3, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Pending', '789 Pine Ln, Anytown', Decimal('25.00')),
#  (4, 4, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Shipped', '101 Elm Rd, Anytown', Decimal('18.20')),
#  (5, 5, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Delivered', '222 Maple Dr, Anytown', Decimal('110.50')),
#  (6, 6, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Pending', '333 Birch Ct, Anytown', Decimal('22.99')),
#  (7, 7, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Shipped', '444 Willow Way, Anytown', Decimal('12.75')),
#  (8, 8, datetime.datetime(2025, 5, 20, 20, 39, 27), 'Delivered', '555 Cedar Blvd, Anytown', Decimal('550.00')),
# ...

# %%
# %%sql
# use lastcourse;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 12 rows affected.
# [('course',),
#  ('customers',),
#  ('data',),
#  ('emp',),
#  ('employee',),
#  ('employees3',),
#  ('my_view',),
#  ('nulls',),
#  ('products',),
#  ('sales',),
#  ('sales_data',),
#  ('student',)]

# %%
# %%sql
# select *
# from sales;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/
# 8 rows affected.
# [(31, 101, 201, datetime.date(2024, 1, 15), 1, 1200),
#  (32, 102, 202, datetime.date(2024, 1, 16), 2, 1600),
#  (33, 102, 201, datetime.date(2024, 1, 17), 1, 1200),
#  (34, 102, 203, datetime.date(2024, 1, 18), 3, 1200),
#  (35, 103, 202, datetime.date(2024, 1, 19), 1, 800),
#  (36, 103, 204, datetime.date(2024, 1, 20), 2, 300),
#  (37, 104, 205, datetime.date(2024, 1, 21), 1, 250),
#  (38, 105, 201, datetime.date(2024, 1, 22), 1, 1200)]

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql
